# %%
import pandas as pd 
import numpy as np 
import math
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('HRDataset.csv')
duplicates = df[df.duplicated()]
len(duplicates)
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (537, 36)

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.head()
# Out:
#               Employee_Name    EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026.0        0.0              0.0       1.0
# 1  Ait Sidi, Karthikeyan     10084.0        1.0              1.0       1.0
# 2         Akinkuolie, Sarah  10196.0        1.0              1.0       0.0
# 3              Alagbe,Trina  10088.0        1.0              1.0       0.0
# 4          Anderson, Carol   10069.0        0.0              2.0       0.0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# 0          1.0     5.0          4.0                     0.0   62506.0  ...
# 1          5.0     3.0          3.0                     0.0  104437.0  ...
# 2          5.0     5.0          3.0                     0.0   64955.0  ...
# 3          1.0     5.0          3.0                     0.0   64991.0  ...
# 4          5.0     5.0          3.0                     0.0   50825.0  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
# 4  Webster Butler       39.0     Google Search      Fully Meets
#
#    EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# 0              4.60             5.0                  0.0
# 1              4.96             3.0                  6.0
# 2              3.02             3.0                  0.0
# 3              4.84             5.0                  0.0
# 4              5.00             4.0                  0.0
#
#   LastPerformanceReview_Date DaysLateLast30 Absences
# 0                  1/17/2019            0.0      1.0
# 1                  2/24/2016            0.0     17.0
# 2                  5/15/2012            0.0      3.0
# 3                   1/3/2019            0.0     15.0
# 4                   2/1/2016            0.0      2.0
#
# [5 rows x 36 columns]

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    524.000000  529.000000       521.000000  528.000000   524.000000
# mean   10155.568702    0.406427         0.833013    0.433712     2.353053
# std       89.423077    0.491631         0.947133    0.496056     1.782475
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.750000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.500000    0.000000         1.000000    0.000000     1.000000
# 75%    10232.000000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  531.000000   530.000000              525.000000     527.000000
# mean     4.629002     2.988679                0.100952   69747.303605
# std      1.049630     0.579962                0.301553   28250.759350
# min      1.000000     1.000000                0.000000   45046.000000
# 25%      5.000000     3.000000                0.000000   55315.000000
# 50%      5.000000     3.000000                0.000000   62425.000000
# 75%      5.000000     3.000000                0.000000   71776.000000
# max      6.000000     4.000000                1.000000  250000.000000
#
#             Termd  PositionID           Zip   ManagerID  EngagementSurvey  \
# count  528.000000  525.000000    525.000000  513.000000        530.000000
# mean     0.359848   16.718095   6366.323810   14.842105          4.089849
# std      0.480411    6.401377  16504.009748    8.280980          0.810309
# min      0.000000    1.000000   1013.000000    1.000000          1.120000
# 25%      0.000000   18.000000   1902.000000   11.000000          3.667500
# 50%      0.000000   19.000000   2132.000000   15.000000          4.295000
# 75%      1.000000   20.000000   2445.000000   20.000000          4.647500
# max      1.000000   30.000000  98052.000000   39.000000          5.000000
#
#        EmpSatisfaction  SpecialProjectsCount  DaysLateLast30    Absences
# count       520.000000            525.000000      524.000000  519.000000
# mean          3.886538              1.278095        0.450382    9.998073
# std           0.937658              2.366028        1.317415    5.997908
# min           1.000000              0.000000        0.000000    1.000000
# 25%           3.000000              0.000000        0.000000    4.000000
# 50%           4.000000              0.000000        0.000000   10.000000
# 75%           5.000000              0.000000        0.000000   15.000000
# max           5.000000              8.000000        6.000000   20.000000

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                         float64
# MarriedID                     float64
# MaritalStatusID               float64
# GenderID                      float64
# EmpStatusID                   float64
# DeptID                        float64
# PerfScoreID                   float64
# FromDiversityJobFairID        float64
# Salary                        float64
# Termd                         float64
# PositionID                    float64
# Position                       object
# State                          object
# Zip                           float64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# Department                     object
# ManagerName                    object
# ManagerID                     float64
# RecruitmentSource              object
# PerformanceScore               object
# EngagementSurvey              float64
# EmpSatisfaction               float64
# SpecialProjectsCount          float64
# LastPerformanceReview_Date     object
# DaysLateLast30                float64
# Absences                      float64
# dtype: object

# %%
for col in df.columns:
    print(col, '\t', df[col].dtype, '\t', df[col].isna().sum())
# Out:
# Employee_Name 	 object 	 14
# EmpID 	 float64 	 13
# MarriedID 	 float64 	 8
# MaritalStatusID 	 float64 	 16
# GenderID 	 float64 	 9
# EmpStatusID 	 float64 	 13
# DeptID 	 float64 	 6
# PerfScoreID 	 float64 	 7
# FromDiversityJobFairID 	 float64 	 12
# Salary 	 float64 	 10
# Termd 	 float64 	 9
# PositionID 	 float64 	 12
# Position 	 object 	 15
# State 	 object 	 15
# Zip 	 float64 	 12
# DOB 	 object 	 17
# Sex 	 object 	 8
# MaritalDesc 	 object 	 15
# CitizenDesc 	 object 	 9
# HispanicLatino 	 object 	 18
# RaceDesc 	 object 	 11
# DateofHire 	 object 	 15
# DateofTermination 	 object 	 215
# TermReason 	 object 	 12
# EmploymentStatus 	 object 	 14
# Department 	 object 	 9
# ManagerName 	 object 	 13
# ManagerID 	 float64 	 24
# RecruitmentSource 	 object 	 15
# PerformanceScore 	 object 	 15
# EngagementSurvey 	 float64 	 7
# EmpSatisfaction 	 float64 	 17
# SpecialProjectsCount 	 float64 	 12
# LastPerformanceReview_Date 	 object 	 8
# DaysLateLast30 	 float64 	 13
# Absences 	 float64 	 18

# %%
df.isnull().sum()
# Out:
# Employee_Name                  14
# EmpID                          13
# MarriedID                       8
# MaritalStatusID                16
# GenderID                        9
# EmpStatusID                    13
# DeptID                          6
# PerfScoreID                     7
# FromDiversityJobFairID         12
# Salary                         10
# Termd                           9
# PositionID                     12
# Position                       15
# State                          15
# Zip                            12
# DOB                            17
# Sex                             8
# MaritalDesc                    15
# CitizenDesc                     9
# HispanicLatino                 18
# RaceDesc                       11
# DateofHire                     15
# DateofTermination             215
# TermReason                     12
# EmploymentStatus               14
# Department                      9
# ManagerName                    13
# ManagerID                      24
# RecruitmentSource              15
# PerformanceScore               15
# EngagementSurvey                7
# EmpSatisfaction                17
# SpecialProjectsCount           12
# LastPerformanceReview_Date      8
# DaysLateLast30                 13
# Absences                       18
# dtype: int64

# %%
df.isnull()
# Out:
#      Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  EmpStatusID  \
# 0            False  False      False            False     False        False
# 1            False  False      False            False     False        False
# 2            False  False      False            False     False        False
# 3            False  False      False            False     False        False
# 4            False  False      False            False     False        False
# ..             ...    ...        ...              ...       ...          ...
# 532          False  False      False            False     False        False
# 533          False  False      False            False     False        False
# 534          False  False      False            False     False        False
# 535          False  False      False            False     False        False
# 536          False  False      False            False     False        False
#
#      DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  ManagerName  \
# 0     False        False                   False   False  ...        False
# 1     False        False                   False   False  ...        False
# 2     False        False                   False   False  ...        False
# 3     False        False                   False   False  ...        False
# 4     False        False                   False   False  ...        False
# ..      ...          ...                     ...     ...  ...          ...
# 532   False        False                   False   False  ...        False
# 533   False        False                   False   False  ...        False
# 534   False        False                   False   False  ...        False
# 535   False        False                   False   False  ...        False
# 536   False        False                   False   False  ...        False
#
#      ManagerID  RecruitmentSource  PerformanceScore  EngagementSurvey  \
# 0        False              False             False             False
# 1        False              False             False             False
# 2        False              False             False             False
# 3        False              False             False             False
# 4        False              False             False             False
# ..         ...                ...               ...               ...
# 532      False              False             False             False
# 533      False              False             False             False
# 534       True              False             False             False
# 535      False               True             False             False
# 536      False              False             False             False
#
#      EmpSatisfaction  SpecialProjectsCount  LastPerformanceReview_Date  \
# 0              False                 False                       False
# 1              False                 False                       False
# 2              False                 False                       False
# 3              False                 False                       False
# 4              False                 False                       False
# ..               ...                   ...                         ...
# 532            False                 False                       False
# 533            False                 False                       False
# 534            False                  True                       False
# 535            False                 False                        True
# 536            False                 False                       False
#
#      DaysLateLast30  Absences
# 0             False     False
# 1             False     False
# 2             False     False
# 3             False     False
# 4             False     False
# ..              ...       ...
# 532           False     False
# 533           False     False
# 534           False     False
# 535           False     False
# 536           False     False
#
# [537 rows x 36 columns]

# %%
df.isnull().any()
# Out:
# Employee_Name                 True
# EmpID                         True
# MarriedID                     True
# MaritalStatusID               True
# GenderID                      True
# EmpStatusID                   True
# DeptID                        True
# PerfScoreID                   True
# FromDiversityJobFairID        True
# Salary                        True
# Termd                         True
# PositionID                    True
# Position                      True
# State                         True
# Zip                           True
# DOB                           True
# Sex                           True
# MaritalDesc                   True
# CitizenDesc                   True
# HispanicLatino                True
# RaceDesc                      True
# DateofHire                    True
# DateofTermination             True
# TermReason                    True
# EmploymentStatus              True
# Department                    True
# ManagerName                   True
# ManagerID                     True
# RecruitmentSource             True
# PerformanceScore              True
# EngagementSurvey              True
# EmpSatisfaction               True
# SpecialProjectsCount          True
# LastPerformanceReview_Date    True
# DaysLateLast30                True
# Absences                      True
# dtype: bool

# %%
df.isna().sum()
# Out:
# Employee_Name                  14
# EmpID                          13
# MarriedID                       8
# MaritalStatusID                16
# GenderID                        9
# EmpStatusID                    13
# DeptID                          6
# PerfScoreID                     7
# FromDiversityJobFairID         12
# Salary                         10
# Termd                           9
# PositionID                     12
# Position                       15
# State                          15
# Zip                            12
# DOB                            17
# Sex                             8
# MaritalDesc                    15
# CitizenDesc                     9
# HispanicLatino                 18
# RaceDesc                       11
# DateofHire                     15
# DateofTermination             215
# TermReason                     12
# EmploymentStatus               14
# Department                      9
# ManagerName                    13
# ManagerID                      24
# RecruitmentSource              15
# PerformanceScore               15
# EngagementSurvey                7
# EmpSatisfaction                17
# SpecialProjectsCount           12
# LastPerformanceReview_Date      8
# DaysLateLast30                 13
# Absences                       18
# dtype: int64

# %%
df = df.drop(columns=[
    'Employee_Name',
    'EmpID',
    'MarriedID',
    'MaritalStatusID',
    'GenderID',
    'EmpStatusID',
    'DeptID',
    'PerfScoreID',
    'PositionID',
    'ManagerID',
    'Zip',
    'DOB',
    'DateofTermination',
    'TermReason',
    'LastPerformanceReview_Date'
], errors='ignore')

# %%
df.isna().sum()
# Out:
# FromDiversityJobFairID    12
# Salary                    10
# Termd                      9
# Position                  15
# State                     15
# Sex                        8
# MaritalDesc               15
# CitizenDesc                9
# HispanicLatino            18
# RaceDesc                  11
# DateofHire                15
# EmploymentStatus          14
# Department                 9
# ManagerName               13
# RecruitmentSource         15
# PerformanceScore          15
# EngagementSurvey           7
# EmpSatisfaction           17
# SpecialProjectsCount      12
# DaysLateLast30            13
# Absences                  18
# dtype: int64

# %%
df.shape
# Out:
# (537, 21)

# %%
numeric_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(12, 10))
correlations = numeric_df.corr(method='pearson')
plt.figure(figsize=(12,10))
sns.heatmap(correlations, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Matrice de Corrélation")
plt.show()

# %%
df.hist(figsize=(15, 15))
plt.show()

# %%
sns.set(style='whitegrid')
ax = sns.boxplot(data = df, orient = 'h')

# %%
outlier_counts = {}
for column in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        
        outliers = ((df[column] < lower_bound) | (df[column] > upper_bound)).sum()
        outlier_counts[column] = outliers
total = 0
for column, count in outlier_counts.items():
    total+=1
    print(f"Colone'{column}': {count} outliers")
print(total)
# Out:
# Colone'FromDiversityJobFairID': 53 outliers
# Colone'Salary': 52 outliers
# Colone'Termd': 0 outliers
# Colone'EngagementSurvey': 20 outliers
# Colone'EmpSatisfaction': 0 outliers
# Colone'SpecialProjectsCount': 126 outliers
# Colone'DaysLateLast30': 64 outliers
# Colone'Absences': 0 outliers
# 8

# %%
df.head()
# Out:
#    FromDiversityJobFairID    Salary  Termd                  Position State  \
# 0                     0.0   62506.0    0.0   Production Technician I    MA
# 1                     0.0  104437.0    1.0                   Sr. DBA    MA
# 2                     0.0   64955.0    1.0  Production Technician II    MA
# 3                     0.0   64991.0    0.0   Production Technician I    MA
# 4                     0.0   50825.0    1.0   Production Technician I    MA
#
#   Sex MaritalDesc CitizenDesc HispanicLatino RaceDesc  ...  \
# 0  M       Single  US Citizen             No    White  ...
# 1  M      Married  US Citizen             No    White  ...
# 2   F     Married  US Citizen             No    White  ...
# 3   F     Married  US Citizen             No    White  ...
# 4   F    Divorced  US Citizen             No    White  ...
#
#          EmploymentStatus         Department     ManagerName  \
# 0                  Active  Production         Michael Albert
# 1  Voluntarily Terminated              IT/IS      Simon Roup
# 2  Voluntarily Terminated  Production         Kissy Sullivan
# 3                  Active  Production           Elijiah Gray
# 4  Voluntarily Terminated  Production         Webster Butler
#
#   RecruitmentSource PerformanceScore EngagementSurvey  EmpSatisfaction  \
# 0          LinkedIn          Exceeds             4.60              5.0
# 1            Indeed      Fully Meets             4.96              3.0
# 2          LinkedIn      Fully Meets             3.02              3.0
# 3            Indeed      Fully Meets             4.84              5.0
# 4     Google Search      Fully Meets             5.00              4.0
#
#    SpecialProjectsCount  DaysLateLast30  Absences
# 0                   0.0             0.0       1.0
# 1                   6.0             0.0      17.0
# 2                   0.0             0.0       3.0
# 3                   0.0             0.0      15.0
# 4                   0.0             0.0       2.0
#
# [5 rows x 21 columns]

# %%
#Return point
df.dropna(inplace=True)
df['Salary'] = df['Salary'] / 12
df.shape
# Out:
# (372, 21)

# %%
X = df.drop('Salary', axis = 1)
Y = df['Salary']
cat_features = X.select_dtypes(include=["object"]).columns.tolist()

# %%
X.head()
# Out:
#    FromDiversityJobFairID  Termd                  Position State Sex  \
# 0                     0.0    0.0   Production Technician I    MA  M
# 1                     0.0    1.0                   Sr. DBA    MA  M
# 2                     0.0    1.0  Production Technician II    MA   F
# 3                     0.0    0.0   Production Technician I    MA   F
# 4                     0.0    1.0   Production Technician I    MA   F
#
#   MaritalDesc CitizenDesc HispanicLatino RaceDesc DateofHire  \
# 0      Single  US Citizen             No    White   7/5/2011
# 1     Married  US Citizen             No    White  3/30/2015
# 2     Married  US Citizen             No    White   7/5/2011
# 3     Married  US Citizen             No    White   1/7/2008
# 4    Divorced  US Citizen             No    White  7/11/2011
#
#          EmploymentStatus         Department     ManagerName  \
# 0                  Active  Production         Michael Albert
# 1  Voluntarily Terminated              IT/IS      Simon Roup
# 2  Voluntarily Terminated  Production         Kissy Sullivan
# 3                  Active  Production           Elijiah Gray
# 4  Voluntarily Terminated  Production         Webster Butler
#
#   RecruitmentSource PerformanceScore  EngagementSurvey  EmpSatisfaction  \
# 0          LinkedIn          Exceeds              4.60              5.0
# 1            Indeed      Fully Meets              4.96              3.0
# 2          LinkedIn      Fully Meets              3.02              3.0
# 3            Indeed      Fully Meets              4.84              5.0
# 4     Google Search      Fully Meets              5.00              4.0
#
#    SpecialProjectsCount  DaysLateLast30  Absences
# 0                   0.0             0.0       1.0
# 1                   6.0             0.0      17.0
# 2                   0.0             0.0       3.0
# 3                   0.0             0.0      15.0
# 4                   0.0             0.0       2.0

# %%
Y.head()
# Out:
# 0    5208.833333
# 1    8703.083333
# 2    5412.916667
# 3    5415.916667
# 4    4235.416667
# Name: Salary, dtype: float64

# %%
X.isnull().any()
# Out:
# FromDiversityJobFairID    False
# Termd                     False
# Position                  False
# State                     False
# Sex                       False
# MaritalDesc               False
# CitizenDesc               False
# HispanicLatino            False
# RaceDesc                  False
# DateofHire                False
# EmploymentStatus          False
# Department                False
# ManagerName               False
# RecruitmentSource         False
# PerformanceScore          False
# EngagementSurvey          False
# EmpSatisfaction           False
# SpecialProjectsCount      False
# DaysLateLast30            False
# Absences                  False
# dtype: bool

# %%
Y.isnull().any()
# Out:
# np.False_

# %%
print(Y.shape)
# Out:
# (372,)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in X.select_dtypes(include='object').columns:
    X[col] = le.fit_transform(X[col].astype(str))

# %%
X.head()
# Out:
#    FromDiversityJobFairID  Termd  Position  State  Sex  MaritalDesc  \
# 0                     0.0    0.0        23     11    1            4
# 1                     0.0    1.0        31     11    1            2
# 2                     0.0    1.0        24     11    0            2
# 3                     0.0    0.0        23     11    0            2
# 4                     0.0    1.0        23     11    0            0
#
#    CitizenDesc  HispanicLatino  RaceDesc  DateofHire  EmploymentStatus  \
# 0            3               1         6          75                 0
# 1            3               1         6          37                 3
# 2            3               1         6          75                 3
# 3            3               1         6           9                 0
# 4            3               1         6          70                 3
#
#    Department  ManagerName  RecruitmentSource  PerformanceScore  \
# 0           3           17                  6                 0
# 1           2           19                  5                 1
# 2           3           15                  6                 1
# 3           3            8                  5                 1
# 4           3           20                  3                 1
#
#    EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  DaysLateLast30  \
# 0              4.60              5.0                   0.0             0.0
# 1              4.96              3.0                   6.0             0.0
# 2              3.02              3.0                   0.0             0.0
# 3              4.84              5.0                   0.0             0.0
# 4              5.00              4.0                   0.0             0.0
#
#    Absences
# 0       1.0
# 1      17.0
# 2       3.0
# 3      15.0
# 4       2.0

# %%
X.isnull().any()
# Out:
# FromDiversityJobFairID    False
# Termd                     False
# Position                  False
# State                     False
# Sex                       False
# MaritalDesc               False
# CitizenDesc               False
# HispanicLatino            False
# RaceDesc                  False
# DateofHire                False
# EmploymentStatus          False
# Department                False
# ManagerName               False
# RecruitmentSource         False
# PerformanceScore          False
# EngagementSurvey          False
# EmpSatisfaction           False
# SpecialProjectsCount      False
# DaysLateLast30            False
# Absences                  False
# dtype: bool

# %%
Y.shape
# Out:
# (372,)

# %%
X = X.values
Y = Y.values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 0)

# %%
X_train.shape
# Out:
# (297, 20)

# %%
X_test.shape
# Out:
# (75, 20)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
X_test_sc[:,:]
# Out:
# array([[-0.32262861, -0.74496565,  0.58375401, ..., -0.53678799,
#         -0.33871443,  0.16942293],
#        [-0.32262861, -0.74496565,  0.46318729, ..., -0.53678799,
#         -0.33871443, -0.17288054],
#        [-0.32262861, -0.74496565,  1.06602087, ...,  1.55541717,
#         -0.33871443, -1.54209444],
#        ...,
#        [-0.32262861,  1.34234377,  0.46318729, ..., -0.53678799,
#         -0.33871443, -0.51518402],
#        [-0.32262861, -0.74496565,  0.46318729, ..., -0.53678799,
#         -0.33871443,  0.16942293],
#        [-0.32262861, -0.74496565,  0.34262057, ..., -0.53678799,
#         -0.33871443,  0.85402988]], shape=(75, 20))

# %%
from sklearn.linear_model import LinearRegression
lr1 = LinearRegression()

# %%
lr1.fit(X_train_sc,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred_LR = lr1.predict(X_test_sc)

# %%
import numpy as np
from sklearn.metrics import *
from sklearn.linear_model import *
from sklearn.neighbors import *
def metriques(name_model, y_test, y_pred):

    print("metriques de " + name_model)

    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test, y_pred)
    medae = median_absolute_error(y_test, y_pred)

    # Affichage
    print(f"MAE: {mae}")
    print(f"MSE: {mse}")
    print(f"RMSE: {rmse}")
    print(f"R²: {r2}")
    print(f"MAPE: {mape}")
    print(f"MedAE: {medae}")

    return r2, mae, mse, rmse, mape, medae

# %%
r2_score_lr, mae_lr, mse_lr, rmse_lr, mape_lr, medae_lr = metriques("LinearRegression", Y_test, Y_pred_LR)
# Out:
# metriques de LinearRegression
# MAE: 1005.2246354188919
# MSE: 2369288.9817397986
# RMSE: 1539.2494865160095
# R²: 0.2576313525315539
# MAPE: 0.1629066746734058
# MedAE: 749.4213176418043

# %%
from sklearn.linear_model import *

# %% [markdown]
# ### Ridge and Lasso

# %%
model_ridge = Ridge()
model_Lasso = Lasso()
model_ridge.fit(X_train_sc, Y_train)
Y_pred_ridge = model_ridge.predict(X_test_sc)
model_Lasso.fit(X_train_sc, Y_train)
Y_pred_Lasso = model_Lasso.predict(X_test_sc)

# %%
r2_score_Ridge, mae_Ridge, mse_Ridge, rmse_Ridge, mape_Ridge, medae_Ridge = metriques("Ridge", Y_test, Y_pred_ridge)
# Out:
# metriques de Ridge
# MAE: 1004.7818959132776
# MSE: 2367663.2117156927
# RMSE: 1538.721291110152
# R²: 0.25814075459402575
# MAPE: 0.16282257130686956
# MedAE: 740.808363306839

# %%
r2_score_Lasso, mae_Lasso, mse_Lasso, rmse_Lasso, mape_Lasso, medae_Lasso = metriques("Lasso", Y_test, Y_pred_Lasso)
# Out:
# metriques de Lasso
# MAE: 1003.8658265688655
# MSE: 2367456.2618431323
# RMSE: 1538.6540422860273
# R²: 0.25820559813914434
# MAPE: 0.1626367703499272
# MedAE: 741.3426817386726

# %% [markdown]
# ### ElasticNet

# %%
elastic_net = ElasticNet(alpha=1.0, l1_ratio=0.5, random_state=42)
elastic_net.fit(X_train_sc, Y_train)
Y_pred_elasticNet = elastic_net.predict(X_test_sc)

# %%
r2_score_Elnet, mae_Elnet, mse_Elnet, rmse_Elnet, mape_Elnet, medae_Elnet = metriques("ElasticNet", Y_test, Y_pred_elasticNet)
# Out:
# metriques de ElasticNet
# MAE: 1031.9930443409585
# MSE: 2391331.5082747107
# RMSE: 1546.3930639635935
# R²: 0.2507247739180434
# MAPE: 0.16667421828869305
# MedAE: 750.5437902165049

# %% [markdown]
# ### Bayesian Regression

# %%
Bayesian = BayesianRidge()
Bayesian.fit(X_train_sc, Y_train)
Y_pred_Bayesian = Bayesian.predict(X_test_sc)

# %%
r2_score_Bayesian, mae_Bayesian, mse_Bayesian, rmse_Bayesian, mape_Bayesian, medae_Bayesian = metriques("BayesianRidge", Y_test, Y_pred_Bayesian)
# Out:
# metriques de BayesianRidge
# MAE: 1023.8188553167837
# MSE: 2366688.2086242517
# RMSE: 1538.4044359739255
# R²: 0.25844625203728777
# MAPE: 0.16541612148127316
# MedAE: 788.250298783817

# %% [markdown]
# ### K-Nearest Neighbors Regression

# %%
KNN = KNeighborsRegressor(n_neighbors=5)
KNN.fit(X_train_sc, Y_train)
Y_pred_knn = KNN.predict(X_test_sc)
r2_score_knn, mae_knn, mse_knn, rmse_knn, mape_knn, medae_knn = metriques("K-Nearest Neighbors Regression", Y_test, Y_pred_knn)
# Out:
# metriques de K-Nearest Neighbors Regression
# MAE: 1022.086
# MSE: 2546795.667144445
# RMSE: 1595.8683113416485
# R²: 0.20201323292856221
# MAPE: 0.15285236604016258
# MedAE: 564.7333333333336

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
randomF = RandomForestRegressor(n_estimators = 200)
randomF.fit(X_train_sc, Y_train)
Y_pred_RF = randomF.predict(X_test_sc)
r2_score_RF, mae_RF, mse_RF, rmse_RF, mape_RF, medae_RF = metriques("RandomForestRegressor", Y_test, Y_pred_RF)
# Out:
# metriques de RandomForestRegressor
# MAE: 806.0833888888889
# MSE: 1900225.4584710272
# RMSE: 1378.4866551661019
# R²: 0.4046028937954316
# MAPE: 0.12671859509746192
# MedAE: 538.2370833333362

# %% [markdown]
# ### Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
DecisionTree = DecisionTreeRegressor()
DecisionTree.fit(X_train_sc, Y_train)
Y_pred_DT = DecisionTree.predict(X_test_sc)
r2_score_DT, mae_DT, mse_DT, rmse_DT, mape_DT, medae_DT = metriques("RandomForestRegressor", Y_test, Y_pred_DT)
# Out:
# metriques de RandomForestRegressor
# MAE: 1458.568888888889
# MSE: 8050325.496111112
# RMSE: 2837.309552394858
# R²: -1.5224062139690009
# MAPE: 0.21230111823672643
# MedAE: 562.666666666667

# %% [markdown]
# ### Extra Trees Regression

# %%
from sklearn.ensemble import ExtraTreesRegressor
randomF = ExtraTreesRegressor(n_estimators = 200)
randomF.fit(X_train_sc, Y_train)
Y_pred_XTR = randomF.predict(X_test_sc)
r2_score_XTR, mae_XTR, mse_XTR, rmse_XTR, mape_XTR, medae_XTR = metriques("ExtraTreesRegressor", Y_test, Y_pred_XTR)
# Out:
# metriques de ExtraTreesRegressor
# MAE: 906.1256444444443
# MSE: 2019933.3822576206
# RMSE: 1421.2436041219748
# R²: 0.36709484384558855
# MAPE: 0.14149748976656754
# MedAE: 628.9629166666682

# %% [markdown]
# ### Gradient Boosting Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor
randomF = GradientBoostingRegressor()
randomF.fit(X_train_sc, Y_train)
Y_pred_GBR = randomF.predict(X_test_sc)
r2_score_GBR, mae_GBR, mse_GBR, rmse_GBR, mape_GBR, medae_GBR = metriques("GradientBoostingRegressor", Y_test, Y_pred_GBR)
# Out:
# metriques de GradientBoostingRegressor
# MAE: 870.6888086651866
# MSE: 2845284.3806723063
# RMSE: 1686.7970775028946
# R²: 0.1084878486237909
# MAPE: 0.14098479943833053
# MedAE: 524.4676623004107

# %% [markdown]
# ### XGBoost Regression

# %%
from xgboost import XGBRegressor
randomF = XGBRegressor()
randomF.fit(X_train_sc, Y_train)
Y_pred_XGBR = randomF.predict(X_test_sc)
r2_score_XGBR, mae_XGBR, mse_XGBR, rmse_XGBR, mape_XGBR, medae_XGBR = metriques("XGBRegressor", Y_test, Y_pred_XGBR)
# Out:
# metriques de XGBRegressor
# MAE: 1000.9900868055556
# MSE: 2973482.1013980997
# RMSE: 1724.378758103364
# R²: 0.06831969299683971
# MAPE: 0.15133777714506452
# MedAE: 606.20556640625

# %% [markdown]
# ### LightGBM Regression

# %%
from lightgbm import LGBMRegressor
randomF = LGBMRegressor()
randomF.fit(X_train_sc, Y_train)
Y_pred_lGBM = randomF.predict(X_test_sc)
r2_score_lGBM, mae_lGBM, mse_lGBM, rmse_lGBM, mape_lGBM, medae_lGBM = metriques("lightgbm", Y_test, Y_pred_lGBM)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000211 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 249
# [LightGBM] [Info] Number of data points in the train set: 297, number of used features: 19
# [LightGBM] [Info] Start training from score 5763.821276
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# metriques de lightgbm
# MAE: 947.8788142484591
# MSE: 1953388.9054279034
# RMSE: 1397.6369004243925
# R²: 0.387945205975875
# MAPE: 0.15409606461546968
# MedAE: 618.6779330076761

# %% [markdown]
# ### CatBoost Regression

# %%
from catboost import CatBoostRegressor
randomF = CatBoostRegressor(verbose=0)
randomF.fit(X_train_sc, Y_train)
Y_pred_CB = randomF.predict(X_test_sc)
r2_score_CB, mae_CB, mse_CB, rmse_CB, mape_CB, medae_CB = metriques("CatBoostRegressor", Y_test, Y_pred_CB)
# Out:
# metriques de CatBoostRegressor
# MAE: 809.4812493533459
# MSE: 1541474.3029554433
# RMSE: 1241.5612360876298
# R²: 0.5170102920277402
# MAPE: 0.13119778052265124
# MedAE: 599.5486658089621

# %% [markdown]
# ### AdaBoost Regression

# %%
from sklearn.ensemble import AdaBoostRegressor
randomF = AdaBoostRegressor()
randomF.fit(X_train_sc, Y_train)
Y_pred_AB = randomF.predict(X_test_sc)
r2_score_AB, mae_AB, mse_AB, rmse_AB, mape_AB, medae_AB = metriques("AdaBoostRegressor", Y_test, Y_pred_AB)
# Out:
# metriques de AdaBoostRegressor
# MAE: 1153.4865376076095
# MSE: 2114396.6243202295
# RMSE: 1454.0964975957509
# R²: 0.3374967028902337
# MAPE: 0.20731329106189111
# MedAE: 981.2681818181836

# %% [markdown]
# ### Support Vector Regression (SVR)

# %%
from sklearn.svm import SVR
randomF = SVR(kernel='rbf')
randomF.fit(X_train_sc, Y_train)
Y_pred_SVR = randomF.predict(X_test_sc)
r2_score_SVR, mae_SVR, mse_SVR, rmse_SVR, mape_SVR, medae_SVR = metriques("SVR", Y_test, Y_pred_SVR)
# Out:
# metriques de SVR
# MAE: 1179.4776427656038
# MSE: 3658162.2336382093
# RMSE: 1912.6322787295549
# R²: -0.1462109394574449
# MAPE: 0.16976917781380907
# MedAE: 611.5002353168065

# %% [markdown]
# ### Kernel Ridge Regression

# %%
from sklearn.kernel_ridge import KernelRidge
randomF = KernelRidge(alpha=1.0, kernel='rbf')
randomF.fit(X_train_sc, Y_train)
Y_pred_KR = randomF.predict(X_test_sc)
r2_score_KR, mae_KR, mse_KR, rmse_KR, mape_KR, medae_KR = metriques("KernelRidge", Y_test, Y_pred_KR)
# Out:
# metriques de KernelRidge
# MAE: 1450.7166275391758
# MSE: 3880873.9614469307
# RMSE: 1969.9933912191002
# R²: -0.21599314222922938
# MAPE: 0.23060616157345673
# MedAE: 1094.9461398106669

# %% [markdown]
# ### Quantile Regression

# %%
from sklearn.linear_model import QuantileRegressor
randomF = QuantileRegressor(quantile=0.9)
randomF.fit(X_train_sc, Y_train)
Y_pred_QR = randomF.predict(X_test_sc)
r2_score_QR, mae_QR, mse_QR, rmse_QR, mape_QR, medae_QR = metriques("QuantileRegressor", Y_test, Y_pred_QR)
# Out:
# metriques de QuantileRegressor
# MAE: 2344.0044444444447
# MSE: 6898537.3205555575
# RMSE: 2626.506676282312
# R²: -1.1615167502323098
# MAPE: 0.4571709694877318
# MedAE: 2519.333333333334

# %% [markdown]
# ### Poisson Regression

# %%
from sklearn.linear_model import PoissonRegressor
randomF = PoissonRegressor()
randomF.fit(X_train_sc, Y_train)
Y_pred_PR = randomF.predict(X_test_sc)
r2_score_PR, mae_PR, mse_PR, rmse_PR, mape_PR, medae_PR = metriques("QuantileRegressor", Y_test, Y_pred_PR)
# Out:
# metriques de QuantileRegressor
# MAE: 1000.6410478388474
# MSE: 2363046.749017667
# RMSE: 1537.2204620735658
# R²: 0.25958722954732805
# MAPE: 0.16109599529613014
# MedAE: 719.3917983009151
